# %% [markdown]
# # Packaging and Deployment
#
# You have been tasked in federating the In this exercise we will be covering the basic components of the flower federated learning package. We will build a basic client, that can interface with our live server. We will also package the client.
#
# We will complete the following steps:
#
#     1.  Write a basic client
#     2.  Dockerize the client
#     3.  Deploy and run federated learning rounds with (hopefully) all workshop participants!
#
# ## Writing a basic client
#
# The client is flower's abstract class that executes the code on the edge. It runs code to train the local model, updates the model parameters from parameters received from the server and runs evaluations on local data. Because the client is an abstract class, some methods do not have a default implementation. These methods are the methods that define how the local model is trained and how parameter updates get sent from the edge to the server.
#
#
#
# **def get_parameters(self, config) -> List:** defines how parameters are extracted from the edge model and how they are sent back to the server. Our server already exists, and expects parameters in a two-dimensional list format, with the format being \[coefficients (NDArrays), intercept (NDArrays)\]. The config parameter is mandatory in this method, but we will not use it in our implementation. Configuration parameters requested by the server. This can be used to tell the client which parameters are needed along with some Scalar attributes.
#
# **def fit(self, parameters, config): -> List, Integer, Dict** defines how the model will be refit, using the parameters passed by the server. The parameters argument is passed by the global (server) model. Configuration parameters allow the server to influence training on the client. It can be used to communicate arbitrary values from the server to the client, for example, to set the number of (local) training epochs. It returns the following three outputs:
#
# &ensp; parameters (NDArrays) – The locally updated model parameters.
#
# &ensp; num_examples (int) – The number of examples used for training.
#
# &ensp; metrics (Dict[str, Scalar]) – A dictionary mapping arbitrary string keys to values of type bool, bytes, float, int, or str. It can be used to communicate arbitrary values back to the server.
#
#
# **def evaluate(self, parameters, config):** Evaluate the provided parameters using the locally held dataset. Returns these outputs:
#
# &ensp; loss (float) – The evaluation loss of the model on the local dataset.
#
# &ensp; num_examples (int) – The number of examples used for evaluation.
#
# &ensp; metrics (Dict[str, Scalar]) – A dictionary mapping arbitrary string keys to values of type bool, bytes, float, int, or str. It can be used to communicate arbitrary values back to the server.
#
#
# We have already written a client class with the skeleton methods below. Implement these methods, and when you're done run the cell. It will write the contents to a client.py file.

# %%
# %%writefile client.py

from flwr.common import NDArrays, Scalar
from sklearn.linear_model import LinearRegression
import numpy as np
import flwr as fl
from sklearn.datasets import fetch_california_housing
from workshop.client.client import partition
from workshop.client.utils import set_initial_params

from typing import Dict, List, Tuple


class CaliforniaHousingClient(fl.client.NumPyClient):
    def __init__(self, partition_id: int):
        self.model = LinearRegression()
        set_initial_params(self.model)

        X, y = fetch_california_housing(return_X_y=True)

        partition_id = np.random.choice(10)

        self.X_train, self.y_train = X[:15000], y[:15000]
        self.X_test, self.y_test = X[15000:], y[15000:]

        self.X_train, self.y_train = partition(
            self.X_train, self.y_train, 10)[partition_id]
        
    def get_parameters(self, config) -> List:
        """Returns the paramters of a sklearn LinearRegression model."""
        return parameters

    def fit(self, parameters, config) -> tuple[NDArrays, int, dict]:
        """Refit the model locally with the central parameters and return them"""
        updated_parameters = parameters
        num_examples = 0
        metrics = {} # Won't be used in this example, we can return it empty

        return updated_parameters, num_examples, metrics
    
    def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]) -> Tuple[float, int, Dict[str, Scalar]]:
        mse = 0
        num_examples = 0
        metrics = {}
        

        return mse, num_examples, metrics
# Out:
# Writing client.py

# %% [markdown]
# Now that we have a working client, we can package and deploy it! Like any good program, our client.py needs an entry point (if \_\_name\_\_ == "\_\_main\_\_") block. In it, we should construct our client, and connect it to the server!
#
# The client n
#
# <span style= 'color:red'> WARNING </font>
#
# The cell below will append the code written in it to the client every time you run it. If you made a mistake, make sure to remove the entry point block from client.py before running this cell again.

# %%
# %%writefile -a client.py

if __name__ == "__main__":
    while True:
        try:
            # pick up the server address from system arguments

            server_address

            client = CaliforniaHousingClient(partition_id=2)
            fl.client.start_numpy_client(
                server_address=server_address, client=client)
            break
        except Exception as e:
            logging.warning(
                "Could not connect to server: sleeping for 5 seconds...")
            time.sleep(5)

# %% [markdown]
# There is a dockerfile included in the exercise folder that you can use. As you can see, the dockerfile runs the client.py file. You can go ahead and copy-paste the **CaliforniaHousingClient** class you wrote into this file. The file also has an entry point (if \_\_name\_\_ == "\_\_main\_\_"). Under the entry point, we construct our client and connect it to the server. We therefore need to pass the server ip address. Let's pass this is a system argument to client.py in the dockerfile.
#
# The dockerfile is already partially written. What is missing, is the environment v the

# %%
# %%writefile dockerfile
#
# FROM python:3.9.16-slim
#
# WORKDIR /usr/src/app
#
# COPY . .
#
# ## ADD IP ENV variable
#
# RUN pip install --no-cache-dir -r requirements.txt
#
# EXPOSE 8080
#
# CMD ["python3", "client.py"]
# Out:
# Writing dockerfile

# %% [markdown]
# Now let's build the docker image

# %%
# !docker build -t client .
# Out:
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      0.1s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      0.2s
# [+] Building 0.5s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      0.4s
# [+] Building 0.6s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      0.5s
# [+] Building 0.8s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      0.7s
# [+] Building 0.9s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      0.8s
# [+] Building 1.1s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.0s
# [+] Building 1.2s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.1s
# [+] Building 1.4s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.3s
# [+] Building 1.5s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.4s
# [+] Building 1.7s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.6s
# [+] Building 1.8s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.7s
# [+] Building 2.0s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      1.9s
# [+] Building 2.1s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.1s
# [+] Building 2.3s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.2s
# [+] Building 2.4s (2/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.4s
# [+] Building 2.5s (3/3)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
# [+] Building 2.7s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               0.1s
# [+] Building 2.8s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               0.3s
# [+] Building 3.0s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               0.4s
# [+] Building 3.1s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               0.6s
# [+] Building 3.3s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               0.7s
# [+] Building 3.4s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               0.9s
# [+] Building 3.6s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.0s
# [+] Building 3.7s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.2s
# [+] Building 3.9s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.3s
# [+] Building 4.0s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.5s
#  => => # Collecting flwr==1.3.0
# [+] Building 4.2s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.6s
#  => => # Collecting flwr==1.3.0
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
# [+] Building 4.3s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.7s
#  => => # Collecting flwr==1.3.0
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
# [+] Building 4.4s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               1.8s
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
# [+] Building 4.6s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.0s
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
# [+] Building 4.7s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.1s
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
# [+] Building 4.9s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.3s
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
# [+] Building 5.0s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.5s
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
# [+] Building 5.2s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.6s
#  => => #   Downloading flwr-1.3.0-py3-none-any.whl (139 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 7.3 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
# [+] Building 5.3s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.7s
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 15.8 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.5s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               2.9s
#  => => # ta 0:00:00
#  => => # Collecting numpy==1.24.2
#  => => #   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (14.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 15.8 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.6s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.1s
#  => => # 014_aarch64.whl (14.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 15.8 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting pandas==1.5.3
#  => => #   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (11.5 MB)
# [+] Building 5.8s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.2s
#  => => # 014_aarch64.whl (14.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 15.8 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting pandas==1.5.3
#  => => #   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (11.5 MB)
# [+] Building 5.9s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.4s
#  => => # 014_aarch64.whl (14.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 15.8 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting pandas==1.5.3
#  => => #   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (11.5 MB)
# [+] Building 6.1s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.5s
#  => => # ta 0:00:00
#  => => # Collecting pandas==1.5.3
#  => => #   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (11.5 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 20.4 MB/s e
#  => => # ta 0:00:00
# [+] Building 6.2s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.6s
#  => => # Collecting pandas==1.5.3
#  => => #   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_aarch64.manylinux2
#  => => # 014_aarch64.whl (11.5 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 20.4 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
# [+] Building 6.3s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.8s
#  => => # 014_aarch64.whl (11.5 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 20.4 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
#  => => #   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_aarch64.many
#  => => # linux2014_aarch64.whl (9.2 MB)
# [+] Building 6.5s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               3.9s
#  => => # 014_aarch64.whl (11.5 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 20.4 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
#  => => #   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_aarch64.many
#  => => # linux2014_aarch64.whl (9.2 MB)
# [+] Building 6.6s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               4.1s
#  => => # 014_aarch64.whl (11.5 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 20.4 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
#  => => #   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_aarch64.many
#  => => # linux2014_aarch64.whl (9.2 MB)
# [+] Building 6.8s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               4.2s
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
#  => => #   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_aarch64.many
#  => => # linux2014_aarch64.whl (9.2 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 16.3 MB/s eta
#  => => #  0:00:00
# [+] Building 6.9s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               4.4s
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
#  => => #   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_aarch64.many
#  => => # linux2014_aarch64.whl (9.2 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 16.3 MB/s eta
#  => => #  0:00:00
# [+] Building 7.1s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt               4.5s
#  => => # ta 0:00:00
#  => => # Collecting scikit-learn==1.2.2
#  => => #   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_aarch64.many
#  => => # linux2014_aarch64.whl (9.2 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 16.3 MB/s eta
#  => => #  0:00:00
# [+] Building 7.2s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
# ...
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, threadpoolctl, six, protobuf, num
#  => => # py, joblib, iterators, grpcio, scipy, python-dateutil, flwr, scikit-le
#  => => # arn, pandas
# [+] Building 16.9s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              14.3s
#  => => #   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, threadpoolctl, six, protobuf, num
#  => => # py, joblib, iterators, grpcio, scipy, python-dateutil, flwr, scikit-le
#  => => # arn, pandas
# [+] Building 17.0s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              14.4s
#  => => #   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, threadpoolctl, six, protobuf, num
#  => => # py, joblib, iterators, grpcio, scipy, python-dateutil, flwr, scikit-le
#  => => # arn, pandas
# [+] Building 17.2s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              14.6s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 22.0.4; however, version 23.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 17.3s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              14.7s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 22.0.4; however, version 23.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 17.5s (7/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              14.9s
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
#  => => # WARNING: You are using pip version 22.0.4; however, version 23.1.2 is
#  => => # available.
#  => => # You should consider upgrading via the '/usr/local/bin/python -m pip in
#  => => # stall --upgrade pip' command.
# [+] Building 17.6s (8/8)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#
#
#
#
#
#
# [+] Building 17.7s (8/9)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.2s
# [+] Building 17.9s (8/9)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 18.0s (8/9)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 18.2s (8/9)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 18.3s (8/9)
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 18.4s (9/9) FINISHED
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 69B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9.16-slim      2.5s
#  => [1/4] FROM docker.io/library/python:3.9.16-slim@sha256:a321a8513911c5  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 51.32kB                                       0.0s
#  => CACHED [2/4] WORKDIR /usr/src/app                                      0.0s
#  => [3/4] COPY . .                                                         0.0s
#  => [4/4] RUN pip install --no-cache-dir -r requirements.txt              15.0s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
#  => => writing image sha256:4e7c1082eeba45761fb5b2faee269c77d62236ec5d144  0.0s
#  => => naming to docker.io/library/client                                  0.0s

# %%
# !docker run client
# Out:
# Traceback (most recent call last):
#   File "/usr/src/app/client.py", line 7, in <module>
#     from workshop.client.client import partition
# ModuleNotFoundError: No module named 'workshop'
